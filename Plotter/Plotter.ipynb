# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#[epoch, train_acc, train_loss, val_acc, val_loss, test_acc]
df1 = pd.read_csv("all/CNN_MLP/eval.csv")
df2 = pd.read_csv("all/Resnet50_MLP/eval.csv")
df3 = pd.read_csv("all/LSTM/eval.csv")
df4 = pd.read_csv("all/WReN/eval.csv")

# %%
X = df1.iloc[:,0]

#CNN_MLP
y11 = df1.iloc[:,1]
y12 = df1.iloc[:,2]
y13 = df1.iloc[:,3]
y14 = df1.iloc[:,4]
y15 = df1.iloc[:,5]

#Resent50_MLP
y21 = df2.iloc[:,1]
y22 = df2.iloc[:,2]
y23 = df2.iloc[:,3]
y24 = df2.iloc[:,4]
y25 = df2.iloc[:,5]

#LSTM
y31 = df3.iloc[:,1]
y32 = df3.iloc[:,2]
y33 = df3.iloc[:,3]
y34 = df3.iloc[:,4]
y35 = df3.iloc[:,5]

#WReN
y41 = df4.iloc[:,1]
y42 = df4.iloc[:,2]
y43 = df4.iloc[:,3]
y44 = df4.iloc[:,4]
y45 = df4.iloc[:,5]

# %%
plt_1 = plt.figure(figsize=(10, 5))
plt.plot(X, y15, color='red', label='CNN_MLP',)
plt.plot(X, y25, color='blue', label='Resent50_MLP')
plt.plot(X, y35, color='green', label='LSTM')
plt.plot(X, y45, color='orange', label='WReN')
plt.legend(loc='upper left')
plt.xlabel('epoch')
plt.ylabel('Test Accuracy')
plt.title('Comparison of all models on I-RAVEN dataset(epoch vs Test Accuracy)')
plt.show()
plt.savefig('epoch_vs_testacc.jpeg')
